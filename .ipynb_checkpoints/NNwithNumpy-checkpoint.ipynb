# %%
import numpy as np

# %%
class Net:
    def __init__(self, topology):
        self.numLayers     = len(topology)
        self.learning_rate = 0.1
        
        self.W1 = np.random.rand(2, 2) #np.array([np.random.randn(2), np.random.randn(2)])
        self.W2 = np.random.rand(1,2) #np.array([np.random.randn(2)])
        
        self.bW1 = np.random.rand(1, 2) #np.array([np.random.randn(2)])
        self.bW2 = np.random.rand(1, 1) #np.array([np.random.randn(2)])
            
    def _sigmoid(self, x):
        return 1/(1 + np.exp(-x))
    
    def _sigmoid_deriv(self, x):
        return self._sigmoid(x) * (1 - self._sigmoid(x))
    
    
    def feedForward(self, input_vectors):
        self.Z1 = np.matmul(input_vectors, self.W1) #+ self.bW1.T #(1x2). (2x2)
        self.A1 = self._sigmoid(self.Z1)
        self.Z2 = np.matmul(self.A1, self.W2.T) #+ self.bW2 #[1x1]
        self.A2 = self.Z2 #self._sigmoid(self.Z2)
        
        
        
        return self.A2
        
    def backProp(self, input_vectors, target):
        dC_dA2 = self.A2 - target 
        dC_dZ2 = dC_dA2 * self._sigmoid_deriv(self.Z2)
        
        breakpoint()
        #dCdW2 = Dc/DZ2 * a1
        dC_dW2 = np.matmul(dC_dZ2, self.A1)
        dC_dW1 = dC_dZ2 * self.W2 * self._sigmoid_deriv(self.Z1)* input_vectors
        
        dW2       = dC_dW2
        dW1       = dC_dW1
        db2       = np.sum(dC_dA2 * self._sigmoid_deriv(self.Z2))
        db1       = np.sum(dC_dA2 * self._sigmoid_deriv(self.Z2) * self.W2 * self._sigmoid_deriv(self.Z1))
        
        return dW1, dW2, db1, db2
        
    def update_params(self, input_vectors, target, dW1, db1, dW2, db2):    
        #updates
        #adjust the weights
        #breakpoint()

        self.W1 = self.W1 - self.learning_rate * dW1
        self.W2 = self.W2 - self.learning_rate * dW2
        #print("W2", self.W2)

        
    #to train the network
    def train(self, input_vectors, targets, iterations):

        for current_iteration in range(iterations):
            #pick a data instance at random
            random_data_index = np.random.randint(len(input_vectors))
            
            input_vector = input_vectors[random_data_index]
            target = targets[random_data_index]
            
            out = self.feedForward(input_vector)
        
            dW1, dW2, db1, db2 = self.backProp(input_vector, target)
            
            self.update_params(input_vector, target, dW1, db1, dW2, db2)
            
            error = np.square(out - target)
            if current_iteration % 100 == 0:

                    print(out)

        return error

# %%
import matplotlib.pyplot as plt
topo = [2, 2, 1] 

input_vectors = np.array(
[
    [3, 1.5],
    [2, 11],
    [4, 1.5],
    [13, 14],
    [3.5, 0.5],
    [2, 10.5],
    [5.5, 13],
    [3, 1],
])

targets = np.array([0, 1, 0, 1, 0, 1, 1, 0])

makeNet = Net(topo)
error = makeNet.train(input_vectors, targets, 10000)
# Out:
# > <ipython-input-4-648b1861861c>(33)backProp()
# -> dC_dW2 = np.matmul(dC_dZ2, self.A1)
# (Pdb) dC_dZ2.shape
# (1,)
# (Pdb) self.A1.shape
# (2,)
# (Pdb) dC_dZ2
# array([0.16408295])
# (Pdb) self.A1
# array([0.9050277 , 0.95742697])
# (Pdb) np.matmul(dC_dZ2, self.A1.T)
# *** ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 2 is different from 1)
# (Pdb) self.W2
# array([[0.79074326, 0.04023248]])
# (Pdb) self.W2.shape
# (1, 2)
# (Pdb) self.Z1.shape
# (2,)
